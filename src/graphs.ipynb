# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams["figure.dpi"] = 300

# %%
loss = pd.read_csv("./frozen-malberta-loss.csv")

plt.plot(loss["train/epoch"], loss["malberta-F1A447cBC2 - train/loss"])
plt.grid(True, "both")
plt.xlabel("Train Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
