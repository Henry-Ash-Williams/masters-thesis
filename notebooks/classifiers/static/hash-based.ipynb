# %%
import utils.data as data
import numpy as np
from sklearn.model_selection import train_test_split

dataset = list(data.MalwareDataset())

# %%
train, test = train_test_split(dataset)
# Out:
# 8336

# %%
def get_hash()
