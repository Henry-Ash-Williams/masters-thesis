# %%
import pandare

# %%
panda = pandare.Panda()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 panda = pandare.Panda()
#
# File ~/Documents/uni/masters-thesis/.venv/lib/python3.10/site-packages/pandare/panda.py:162, in Panda.__init__(self, arch, mem, expect_prompt, serial_kwargs, os_version, qcow, os, generic, raw_monitor, extra_args, catch_exceptions, libpanda_path, biospath, plugin_path)
#     160     environ["PANDA_LIB"] = self.libpanda_path = libpanda_path
#     161 else:
# --> 162     build_dir = self.get_build_dir()
#     163     lib_paths = ["libpanda-{0}.so".format(self.arch_name), "{0}-softmmu/libpanda-{0}.so".format(self.arch_name)]
#     164     # Select the first path that exists - we'll have libpanda-{arch}.so for a system install versus arch-softmmu/libpanda-arch.so for a build
#
# ...
