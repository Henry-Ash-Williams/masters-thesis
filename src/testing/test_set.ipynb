# %%
import os 

BASE = '/Volumes/New Volume/malware-detection-dataset/unobfuscated-exes/'
OBFUSCATED = os.path.join(BASE, 'obfuscated')

files = [os.path.join(BASE, f) for f in os.listdir(BASE)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 BASE = '/Volumes/New Volume/malware-detection-dataset/unobfuscated-exes/'
#       4 OBFUSCATED = os.path.join(BASE, 'obfuscated')
# ----> 5 files = [os.path.join(BASE, f) for f in os.listdir(BASE)]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/New Volume/malware-detection-dataset/unobfuscated-exes/'

# %%
def run_analysis(path):
